# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
cat_c = []
for i in range(23):
    cat_c.append('c'+str(i+1))
cat_c_num = [30, 40, 15, 10, 40, 35, 30, 30, 22, 5, 45, 30, 35, 45, 30, 30, 30, 30, 17, 38, 38, 37, 38]

cat_r = []
for i in range(34):
    cat_r.append('r'+str(i+1))
cat_r_num = [30, 40, 15, 10, 40, 35, 30, 30, 22, 5, 45, 30, 35, 45, 30, 30, 30, 30, 17, 40, 8, 42, 18, 40, 30, 15, 25, 45, 52, 30, 6, 30, 35, 35]

# %%
df_c = pd.DataFrame({'C23':cat_c, 'Number':cat_c_num})
df_r = pd.DataFrame({'R34':cat_r, 'Number':cat_r_num})

# %%
df_c['Number'].describe()
# Out:
# count    23.000000
# mean     30.434783
# std      10.487335
# min       5.000000
# 25%      30.000000
# 50%      30.000000
# 75%      38.000000
# max      45.000000
# Name: Number, dtype: float64

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 12
BIGGER_SIZE = 18

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
plt.figure(figsize=(15,4))
sns.set_style("ticks", {'axes.grid' : True})
plt.xticks(rotation=90)
ax = sns.barplot(x='C23', y='Number', data=df_c, color='#3F466E')
ax.bar_label(ax.containers[0])
#for i, v in enumerate(df_c['Number']):
#    plt.text(i - 0.22 , v + 0.8, v)
plt.xlabel(None)
plt.ylabel(None)
plt.ylim(0, 50)
plt.savefig('../result/c23_bar.png', bbox_inches='tight', transparent=True)

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=90)
ax = sns.barplot(x='R34', y='Number', data=df_r, color='#3F466E')
ax.bar_label(ax.containers[0])
#for i, v in enumerate(df_r['Number']):
#   plt.text(i - 0.35 , v + 0.8, v)
plt.xlabel(None)
plt.ylabel(None)
plt.ylim(0, 60)
plt.savefig('../result/r34_bar.png', bbox_inches='tight', transparent=True)

# %%
plt.figure(figsize=(15,8))
#gs = gridspec.GridSpec(2, 1, 1) 
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.45)
plt.subplot(2, 1, 1)
sns.set_style("ticks", {'axes.grid' : True})
plt.xticks(rotation=90)
ax = sns.barplot(x='C23', y='Number', data=df_c, color='#3F466E')
ax.bar_label(ax.containers[0])
#for i, v in enumerate(df_c['Number']):
#    plt.text(i - 0.22 , v + 0.8, v)
plt.xlabel('(a) C23')
plt.ylabel(None)
plt.ylim(0, 50)

plt.subplot(2, 1, 2)
plt.xticks(rotation=90)
ax = sns.barplot(x='R34', y='Number', data=df_r, color='#3F466E')
ax.bar_label(ax.containers[0])
#for i, v in enumerate(df_r['Number']):
#   plt.text(i - 0.35 , v + 0.8, v)
plt.xlabel('(b) R34')
plt.ylabel(None)
plt.ylim(0, 60)
plt.savefig('../result/testset_bar.eps', format='eps', bbox_inches='tight', transparent=True)
plt.savefig('../result/testset_bar.png', bbox_inches='tight', transparent=True)

# %%
plt.figure(figsize=(15,4))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1]) 
plt.subplot(gs[0])
plt.xticks(rotation=90)
ax = sns.barplot(x='C23', y='Number', data=df_c, color='#3F466E')
ax.bar_label(ax.containers[0])
#for i, v in enumerate(df_c['Number']):
#    plt.text(i - 0.32 , v + 0.5, v)
ax.set(xlabel=None)
ax.set(ylabel=None)
ax.set(ylim=(0, 50))
plt.subplot(gs[1])
ax = sns.distplot(df_c['Number'], hist=False, rug=True)
ax.set(xlabel=None)
ax.set(ylabel=None)
#plt.savefig('../result/c23_dist.png', bbox_inches='tight', transparent=True)
# Out:
# /var/folders/tc/3ygrqm8d09n398fpqgjd3pvh0000gn/T/ipykernel_29205/3018172196.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_c['Number'], hist=False, rug=True)
# [Text(0, 0.5, '')]

# %%
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
ax = sns.distplot(df_c['Number'])
ax.set(xlabel=None)
plt.subplot(1,2,2)
ax = sns.boxplot(df_c['Number'])
ax.set(xlabel=None)
# Out:
# /var/folders/tc/3ygrqm8d09n398fpqgjd3pvh0000gn/T/ipykernel_29205/1448039969.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_c['Number'])
# [Text(0.5, 0, '')]

# %%
plt.figure(figsize=(15,4))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1]) 
plt.subplot(gs[0])
plt.xticks(rotation=90)
ax = sns.barplot(x='R34', y='Number', data=df_r, color='#3F466E')
ax.bar_label(ax.containers[0])
#for i, v in enumerate(df_r['Number']):
#    plt.text(i - 0.44 , v + 0.5, v)
ax.set(xlabel=None)
ax.set(ylabel=None)
ax.set(ylim=(0, 60))
plt.subplot(gs[1])
ax = sns.distplot(df_r['Number'], hist=False, rug=True)
ax.set(xlabel=None)
ax.set(ylabel=None)
#plt.savefig('../result/r34_dist.png', bbox_inches='tight', transparent=True)
# Out:
# /var/folders/tc/3ygrqm8d09n398fpqgjd3pvh0000gn/T/ipykernel_29205/823649033.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_r['Number'], hist=False, rug=True)
# [Text(0, 0.5, '')]

# %%
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
ax = sns.distplot(df_r['Number'])
ax.set(xlabel=None)
plt.subplot(1,2,2)
ax = sns.boxplot(df_r['Number'])
ax.set(xlabel=None)
# Out:
# /var/folders/tc/3ygrqm8d09n398fpqgjd3pvh0000gn/T/ipykernel_29205/3185195194.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_r['Number'])
# [Text(0.5, 0, '')]

# %%
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
sns.boxplot(df_c['Number'])
plt.subplot(1,2,2)
sns.boxplot(df_r['Number'])
# Out:
# <AxesSubplot: >

# %%
sns.displot(df_c['Number'], kde=True)
sns.displot(df_r['Number'], kde=True)

# %%
sns.distplot(df_c['Number'], hist=False)
sns.distplot(df_r['Number'], hist=False, kde_kws={'linestyle':'--'})
plt.legend(labels=["C23","R34"], title = "Category")
plt.xlabel(None)
plt.ylabel(None)
# Out:
# /var/folders/tc/3ygrqm8d09n398fpqgjd3pvh0000gn/T/ipykernel_29205/1118960860.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_c['Number'], hist=False)
# /var/folders/tc/3ygrqm8d09n398fpqgjd3pvh0000gn/T/ipykernel_29205/1118960860.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_r['Number'], hist=False, kde_kws={'linestyle':'--'})
# Text(0, 0.5, '')
