# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_ari_lambda = pd.read_csv('../result/jideca_ari_means_lambda.csv')
df_nmi_lambda = pd.read_csv('../result/jideca_nmi_means_lambda.csv')
df_purity_lambda = pd.read_csv('../result/jideca_purity_means_lambda.csv')

# %%
df_ari_34 = df_ari_lambda.loc[df_ari_lambda['class'] == 'R34'].sort_values(by='simple')
df_nmi_34 = df_nmi_lambda.loc[df_nmi_lambda['class'] == 'R34'].sort_values(by='simple')
df_purity_34 = df_purity_lambda.loc[df_purity_lambda['class'] == 'R34'].sort_values(by='simple')

df_ari_23 = df_ari_lambda.loc[df_ari_lambda['class'] == 'C23'].sort_values(by='simple')
df_nmi_23 = df_nmi_lambda.loc[df_nmi_lambda['class'] == 'C23'].sort_values(by='simple')
df_purity_23 = df_purity_lambda.loc[df_purity_lambda['class'] == 'C23'].sort_values(by='simple')

# %%
df_ari_34['types'] = r'$\beta$=0.2, $\gamma$=0.1 (R34)'
df_ari_34.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_ari_23['types'] = r'$\beta$=0.5, $\gamma$=0.1 (C23)'
df_ari_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

df_nmi_34['types'] = r'$\beta$=0.2, $\gamma$=0.1 (R34)'
df_nmi_34.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_nmi_23['types'] = r'$\beta$=0.5, $\gamma$=0.1 (C23)'
df_nmi_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

df_purity_34['types'] = r'$\beta$=0.2, $\gamma$=0.1 (R34)'
df_purity_34.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_purity_23['types'] = r'$\beta$=0.5, $\gamma$=0.1 (C23)'
df_purity_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

# %%
df_ari = pd.concat([df_ari_34, df_ari_23], ignore_index=True)
df_ari = df_ari.astype({'simple':'str'})

df_nmi = pd.concat([df_nmi_34, df_nmi_23], ignore_index=True)
df_nmi = df_nmi.astype({'simple':'str'})

df_purity = pd.concat([df_purity_34, df_purity_23], ignore_index=True)
df_purity = df_purity.astype({'simple':'str'})

# %%
df_ari
# Out:
#      ari simple                            types class
# 0  0.079    0.1  $\beta$=0.2, $\gamma$=0.1 (R34)   R34
# 1  0.170    0.3  $\beta$=0.2, $\gamma$=0.1 (R34)   R34
# 2  0.347    0.5  $\beta$=0.2, $\gamma$=0.1 (R34)   R34
# 3  0.263    0.7  $\beta$=0.2, $\gamma$=0.1 (R34)   R34
# 4  0.240    0.9  $\beta$=0.2, $\gamma$=0.1 (R34)   R34
# 5  0.095    0.1  $\beta$=0.5, $\gamma$=0.1 (C23)   C23
# 6  0.012    0.3  $\beta$=0.5, $\gamma$=0.1 (C23)   C23
# 7  0.329    0.5  $\beta$=0.5, $\gamma$=0.1 (C23)   C23
# 8  0.294    0.7  $\beta$=0.5, $\gamma$=0.1 (C23)   C23
# 9  0.101    0.9  $\beta$=0.5, $\gamma$=0.1 (C23)   C23

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 14

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
plt.figure(figsize=(8,5))
sns.set_style("ticks", {'axes.grid' : True})
colors = ['#455E85', '#D68835']
sns.lineplot(x='simple', y='ari', data=df_ari, linewidth=3, palette=colors, hue='class', style='class', markers=True, markersize=14)
#for i in df_ari.groupby('types'):
#    for x,y,m in i[1][['simple','ari','ari']].values:
#        if x == '0.1': i = 0
#        elif x == '0.3': i = 1
#        elif x == '0.5': i = 2
#        elif x == '1.0': i = 3
#        else: i = 4
#        plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0, 0.4)
plt.ylabel('ARI', fontsize=16)
plt.xlabel(r'$\lambda$')
plt.legend(loc='best')

# %%
plt.figure(figsize=(8,5))
sns.set_style("ticks", {'axes.grid' : True})
#colors = ['#455E85', '#D68835', '#466B3D']
sns.lineplot(x='simple', y='nmi', data=df_nmi, linewidth=3, palette=colors, hue='class', style='class', markers=True, markersize=14)
#for i in df_nmi.groupby('class'):
#    for x,y,m in i[1][['simple','nmi','nmi']].values:
#        if x == '0.1': i = 0
#        elif x == '0.3': i = 1
#        elif x == '0.5': i = 2
#        elif x == '0.7': i = 3
#        else: i = 4
#        plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.16, 0.65)
plt.ylabel('NMI', fontsize=16)
plt.xlabel(r'$\lambda$')
plt.legend(loc='best')

# %%
plt.figure(figsize=(8,5))
sns.set_style("ticks", {'axes.grid' : True})
#colors = ['#455E85', '#D68835', '#466B3D']
sns.lineplot(x='simple', y='purity', data=df_purity, linewidth=3, palette=colors, hue='class', style='class', markers=True, markersize=14)
#for i in df_purity.groupby('types'):
#    for x,y,m in i[1][['simple','purity','purity']].values:
#        if x == '0.1': i = 0
#        elif x == '0.2': i = 1
#        elif x == '0.5': i = 2
#        elif x == '1.0': i = 3
#        else: i = 4
#        plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.1, 0.4)
plt.ylabel('Purity', fontsize=16)
plt.xlabel(r'$\lambda$')
plt.legend(loc='best')

# %%
plt.figure(figsize=(12,3))
sns.set_style("ticks", {'axes.grid' : True})
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.35, hspace=0.35)
colors = ['#455E85', '#D68835']

plt.subplot(1, 3, 1)
ax1 = sns.lineplot(x='simple', y='ari', data=df_ari, linewidth=3, palette=colors, hue='class', style='class', markers=True, markersize=14)
plt.ylim(0, 0.4)
plt.xlabel(r'$\lambda$')
plt.ylabel('ARI', fontsize=16)
ax1.get_legend().remove()

plt.subplot(1, 3, 2)
ax2 = sns.lineplot(x='simple', y='nmi', data=df_nmi, linewidth=3, palette=colors, hue='class', style='class', markers=True, markersize=14)
plt.ylim(0.16, 0.65)
plt.xlabel(r'$\lambda$')
plt.ylabel('NMI', fontsize=16)
ax2.get_legend().remove()

plt.subplot(1, 3, 3)
ax3 = sns.lineplot(x='simple', y='purity', data=df_purity, linewidth=3, palette=colors, hue='class', style='class', markers=True, markersize=14)
plt.ylim(0.1, 0.4)
plt.xlabel(r'$\lambda$')
plt.ylabel('Purity', fontsize=16)
ax3.get_legend().remove()
_label = ["β=0.2 (R34)", "β=0.5 (C23)"]
#_label = ["R34", "C23"]
plt.legend(bbox_to_anchor=(-0.95, 1.2), loc="upper center", ncol=3, labels=_label)

plt.savefig('../result/jideca_lambda.png', format='png', bbox_inches='tight', transparent=True, dpi=300)
plt.savefig('../result/jideca_lambda.eps', format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(10,3))
sns.set_style("ticks", {'axes.grid' : True})
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.35, hspace=0.35)
colors = ['#455E85', '#D68835']

plt.subplot(1, 2, 1)
ax1 = sns.lineplot(x='simple', y='ari', data=df_ari, linewidth=3, palette=colors, hue='class', style='class', markers=True, markersize=14)
plt.ylim(0, 0.4)
plt.xlabel(r'$\lambda$')
plt.ylabel('ARI', fontsize=16)
ax1.get_legend().remove()

plt.subplot(1, 2, 2)
ax2 = sns.lineplot(x='simple', y='nmi', data=df_nmi, linewidth=3, palette=colors, hue='class', style='class', markers=True, markersize=14)
plt.ylim(0.16, 0.65)
plt.xlabel(r'$\lambda$')
plt.ylabel('NMI', fontsize=16)
ax2.get_legend().remove()

_label = ["β=0.2 (R34)", "β=0.5 (C23)"]
#_label = ["R34", "C23"]
plt.legend(bbox_to_anchor=(-0.25, 1.2), loc="upper center", ncol=2, labels=_label)

plt.savefig('../result/jideca_lambda_1.png', format='png', bbox_inches='tight', transparent=True, dpi=300)
plt.savefig('../result/jideca_lambda_1.eps', format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
