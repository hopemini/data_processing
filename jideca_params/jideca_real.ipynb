# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_ari_b05g001_23 = pd.read_csv('../result/jideca_ari_means_b05g001_23.csv')
df_nmi_b05g001_23 = pd.read_csv('../result/jideca_nmi_means_b05g001_23.csv')
df_purity_b05g001_23 = pd.read_csv('../result/jideca_purity_means_b05g001_23.csv')

df_ari_b02g001 = pd.read_csv('../result/jideca_ari_means_b02g001_34.csv')
df_nmi_b02g001 = pd.read_csv('../result/jideca_nmi_means_b02g001_34.csv')
df_purity_b02g001 = pd.read_csv('../result/jideca_purity_means_b02g001_34.csv')

df_ari_b02 = pd.read_csv('../result/jideca_ari_means_b02.csv')
df_nmi_b02 = pd.read_csv('../result/jideca_nmi_means_b02.csv')
df_purity_b02 = pd.read_csv('../result/jideca_purity_means_b02.csv')

df_ari_b05_23 = pd.read_csv('../result/jideca_ari_means_b05_23.csv')
df_nmi_b05_23 = pd.read_csv('../result/jideca_nmi_means_b05_23.csv')
df_purity_b05_23 = pd.read_csv('../result/jideca_purity_means_b05_23.csv')

df_ari_g01 = pd.read_csv('../result/jideca_ari_means_g01.csv')
df_nmi_g01 = pd.read_csv('../result/jideca_nmi_means_g01.csv')
df_purity_g01 = pd.read_csv('../result/jideca_purity_means_g01.csv')

df_ari_g01_23 = pd.read_csv('../result/jideca_ari_means_g01_23.csv')
df_nmi_g01_23 = pd.read_csv('../result/jideca_nmi_means_g01_23.csv')
df_purity_g01_23 = pd.read_csv('../result/jideca_purity_means_g01_23.csv')

df_ari_b001g01_23 = pd.read_csv('../result/jideca_ari_means_b001g01_23.csv')
df_nmi_b001g01_23 = pd.read_csv('../result/jideca_nmi_means_b001g01_23.csv')
df_purity_b001g01_23 = pd.read_csv('../result/jideca_purity_means_b001g01_23.csv')

df_ari_b001g01_34 = pd.read_csv('../result/jideca_ari_means_b001g01_34.csv')
df_nmi_b001g01_34 = pd.read_csv('../result/jideca_nmi_means_b001g01_34.csv')
df_purity_b001g01_34 = pd.read_csv('../result/jideca_purity_means_b001g01_34.csv')

# %%
df_ari_b02 = df_ari_b02.sort_values(by='simple')
df_nmi_b02 = df_nmi_b02.sort_values(by='simple')
df_purity_b02 = df_purity_b02.sort_values(by='simple')

df_ari_b05_23 = df_ari_b05_23.loc[df_ari_b05_23['types'] == 'real'].sort_values(by='simple')
df_nmi_b05_23 = df_nmi_b05_23.loc[df_nmi_b05_23['types'] == 'real'].sort_values(by='simple')
df_purity_b05_23 = df_purity_b05_23.loc[df_purity_b05_23['types'] == 'real'].sort_values(by='simple')

df_ari_g01 = df_ari_g01.loc[df_ari_g01['types'] == 'real'].sort_values(by='simple')
df_nmi_g01 = df_nmi_g01.loc[df_nmi_g01['types'] == 'real'].sort_values(by='simple')
df_purity_g01 = df_purity_g01.loc[df_purity_g01['types'] == 'real'].sort_values(by='simple')

df_ari_g01_23 = df_ari_g01_23.loc[df_ari_g01_23['types'] == 'real'].sort_values(by='simple')
df_nmi_g01_23 = df_nmi_g01_23.loc[df_nmi_g01_23['types'] == 'real'].sort_values(by='simple')
df_purity_g01_23 = df_purity_g01_23.loc[df_purity_g01_23['types'] == 'real'].sort_values(by='simple')

# %%
df_ari_b02 = pd.concat([df_ari_b02g001, df_ari_b02], ignore_index=True)
df_nmi_b02 = pd.concat([df_nmi_b02g001, df_nmi_b02], ignore_index=True)
df_purity_b02 = pd.concat([df_purity_b02g001, df_purity_b02], ignore_index=True)

df_ari_b05_23 = pd.concat([df_ari_b05g001_23, df_ari_b05_23], ignore_index=True)
df_nmi_b05_23 = pd.concat([df_nmi_b05g001_23, df_nmi_b05_23], ignore_index=True)
df_purity_b05_23 = pd.concat([df_purity_b05g001_23, df_purity_b05_23], ignore_index=True)

df_ari_g01 = pd.concat([df_ari_b001g01_34, df_ari_g01], ignore_index=True)
df_nmi_g01 = pd.concat([df_nmi_b001g01_34, df_nmi_g01], ignore_index=True)
df_purity_g01 = pd.concat([df_purity_b001g01_34, df_purity_g01], ignore_index=True)

df_ari_g01_23 = pd.concat([df_ari_b001g01_23, df_ari_g01_23], ignore_index=True)
df_nmi_g01_23 = pd.concat([df_nmi_b001g01_23, df_nmi_g01_23], ignore_index=True)
df_purity_g01_23 = pd.concat([df_purity_b001g01_23, df_purity_g01_23], ignore_index=True)

# %%
df_ari_b02['types'] = r'$\beta$=0.2 (R34)'
df_ari_b02.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_ari_b05_23['types'] = r'$\beta$=0.5 (C23)'
df_ari_b05_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

df_nmi_b02['types'] = r'$\beta$=0.2 (R34)'
df_nmi_b02.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_nmi_b05_23['types'] = r'$\beta$=0.5 (C23)'
df_nmi_b05_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

df_purity_b02['types'] = r'$\beta$=0.2 (R34)'
df_purity_b02.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_purity_b05_23['types'] = r'$\beta$=0.5 (C23)'
df_purity_b05_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

df_ari_g01['types'] = r'$\gamma$=0.1 (R34)'
df_ari_g01.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_ari_g01_23['types'] = r'$\gamma$=0.1 (C23)'
df_ari_g01_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

df_nmi_g01['types'] = r'$\gamma$=0.1 (R34)'
df_nmi_g01.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_nmi_g01_23['types'] = r'$\gamma$=0.1 (C23)'
df_nmi_g01_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

df_purity_g01['types'] = r'$\gamma$=0.1 (R34)'
df_purity_g01.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)
df_purity_g01_23['types'] = r'$\gamma$=0.1 (C23)'
df_purity_g01_23.drop(['Unnamed: 0', 'parameters'], axis=1, inplace=True)

# %%
df_ari = pd.concat([df_ari_b02, df_ari_b05_23], ignore_index=True)
df_ari = df_ari.astype({'simple':'str'})

df_nmi = pd.concat([df_nmi_b02, df_nmi_b05_23], ignore_index=True)
df_nmi = df_nmi.astype({'simple':'str'})

df_purity = pd.concat([df_purity_b02, df_purity_b05_23], ignore_index=True)
df_purity = df_purity.astype({'simple':'str'})

df_ari_g = pd.concat([df_ari_g01, df_ari_g01_23], ignore_index=True)
df_ari_g = df_ari_g.astype({'simple':'str'})

df_nmi_g = pd.concat([df_nmi_g01, df_nmi_g01_23], ignore_index=True)
df_nmi_g = df_nmi_g.astype({'simple':'str'})

df_purity_g = pd.concat([df_purity_g01, df_purity_g01_23], ignore_index=True)
df_purity_g = df_purity_g.astype({'simple':'str'})

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 14

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
plt.figure(figsize=(8,5))
sns.set_style("ticks", {'axes.grid' : True})
colors = ['#455E85', '#D68835']
sns.lineplot(x='simple', y='ari', data=df_ari, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_ari.groupby('types'):
    for x,y,m in i[1][['simple','ari','ari']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0, 0.4)
plt.ylabel('ARI', fontsize=16)
plt.xlabel(r'$\gamma$')
plt.legend(loc='best')

# %%
plt.figure(figsize=(8,5))
sns.set_style("ticks", {'axes.grid' : True})
#colors = ['#455E85', '#D68835', '#466B3D']
sns.lineplot(x='simple', y='nmi', data=df_nmi, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_nmi.groupby('types'):
    for x,y,m in i[1][['simple','nmi','nmi']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.24, 0.65)
plt.ylabel('NMI', fontsize=16)
plt.xlabel(r'$\gamma$')
plt.legend(loc='best')

# %%
plt.figure(figsize=(8,5))
sns.set_style("ticks", {'axes.grid' : True})
#colors = ['#455E85', '#D68835', '#466B3D']
sns.lineplot(x='simple', y='purity', data=df_purity, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_purity.groupby('types'):
    for x,y,m in i[1][['simple','purity','purity']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.15, 0.4)
plt.ylabel('Purity', fontsize=16)
plt.xlabel(r'$\gamma$')
plt.legend(loc='best')

# %%
plt.figure(figsize=(12,4))
sns.set_style("ticks", {'axes.grid' : True})
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.35, hspace=0.35)
colors = ['#455E85', '#D68835']

plt.subplot(1, 3, 1)
ax1 = sns.lineplot(x='simple', y='ari', data=df_ari, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_ari.groupby('types'):
    for x,y,m in i[1][['simple','ari','ari']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0, 0.4)
plt.xlabel(r'$\gamma$')
plt.ylabel('ARI', fontsize=16)
ax1.get_legend().remove()

plt.subplot(1, 3, 2)
ax2 = sns.lineplot(x='simple', y='nmi', data=df_nmi, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_nmi.groupby('types'):
    for x,y,m in i[1][['simple','nmi','nmi']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.24, 0.65)
plt.xlabel(r'$\gamma$')
plt.ylabel('NMI', fontsize=16)
ax2.get_legend().remove()

plt.subplot(1, 3, 3)
ax3 = sns.lineplot(x='simple', y='purity', data=df_purity, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_purity.groupby('types'):
    for x,y,m in i[1][['simple','purity','purity']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.15, 0.4)
plt.xlabel(r'$\gamma$')
plt.ylabel('Purity', fontsize=16)
ax3.get_legend().remove()
plt.legend(bbox_to_anchor=(-0.95, 1.2), loc="upper center", ncol=6)

plt.savefig('../result/jideca_real.png', format='png', bbox_inches='tight', transparent=True)
plt.savefig('../result/jideca_real.eps', format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(12,4))
sns.set_style("ticks", {'axes.grid' : True})
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.35, hspace=0.35)
colors = ['#455E85', '#D68835']

plt.subplot(1, 3, 1)
ax1 = sns.lineplot(x='simple', y='ari', data=df_ari_g, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_ari_g.groupby('types'):
    for x,y,m in i[1][['simple','ari','ari']].values:
        if x == '0.01' : i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.15, 0.38)
plt.xlabel(r'$\beta$')
plt.ylabel('ARI', fontsize=16)
ax1.get_legend().remove()

plt.subplot(1, 3, 2)
ax2 = sns.lineplot(x='simple', y='nmi', data=df_nmi_g, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_nmi_g.groupby('types'):
    for x,y,m in i[1][['simple','nmi','nmi']].values:
        if x == '0.01' : i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.48, 0.62)
plt.xlabel(r'$\beta$')
plt.ylabel('NMI', fontsize=16)
ax2.get_legend().remove()

plt.subplot(1, 3, 3)
ax3 = sns.lineplot(x='simple', y='purity', data=df_purity_g, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_purity_g.groupby('types'):
    for x,y,m in i[1][['simple','purity','purity']].values:
        if x == '0.01' : i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.20, 0.38)
plt.xlabel(r'$\beta$')
plt.ylabel('Purity', fontsize=16)
ax3.get_legend().remove()
plt.legend(bbox_to_anchor=(-0.95, 1.2), loc="upper center", ncol=6)

plt.savefig('../result/jideca_real_g.png', format='png', bbox_inches='tight', transparent=True)
plt.savefig('../result/jideca_real_g.eps', format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(15,8))
sns.set_style("ticks", {'axes.grid' : True})
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.35, hspace=0.4)
colors = ['#455E85', '#D68835']

plt.subplot(2, 3, 1)
ax4 = sns.lineplot(x='simple', y='ari', data=df_ari_g, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_ari_g.groupby('types'):
    for x,y,m in i[1][['simple','ari','ari']].values:
        if x == '0.01' : i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.15, 0.38)
plt.xlabel(r'$\beta$')
plt.ylabel('ARI', fontsize=16)
ax4.get_legend().remove()

plt.subplot(2, 3, 2)
ax5 = sns.lineplot(x='simple', y='nmi', data=df_nmi_g, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_nmi_g.groupby('types'):
    for x,y,m in i[1][['simple','nmi','nmi']].values:
        if x == '0.01' : i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.48, 0.62)
plt.xlabel(r'$\beta$')
plt.ylabel('NMI', fontsize=16)
ax5.get_legend().remove()

plt.subplot(2, 3, 3)
ax6 = sns.lineplot(x='simple', y='purity', data=df_purity_g, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_purity_g.groupby('types'):
    for x,y,m in i[1][['simple','purity','purity']].values:
        if x == '0.01' : i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.20, 0.38)
plt.xlabel(r'$\beta$')
plt.ylabel('Purity', fontsize=16)
ax6.get_legend().remove()
plt.legend(bbox_to_anchor=(-0.95, 1.2), loc="upper center", ncol=6)

plt.subplot(2, 3, 4)
ax1 = sns.lineplot(x='simple', y='ari', data=df_ari, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_ari.groupby('types'):
    for x,y,m in i[1][['simple','ari','ari']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0, 0.4)
plt.xlabel(r'$\gamma$')
plt.ylabel('ARI', fontsize=16)
ax1.get_legend().remove()

plt.subplot(2, 3, 5)
ax2 = sns.lineplot(x='simple', y='nmi', data=df_nmi, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_nmi.groupby('types'):
    for x,y,m in i[1][['simple','nmi','nmi']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.24, 0.65)
plt.xlabel(r'$\gamma$')
plt.ylabel('NMI', fontsize=16)
ax2.get_legend().remove()

plt.subplot(2, 3, 6)
ax3 = sns.lineplot(x='simple', y='purity', data=df_purity, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_purity.groupby('types'):
    for x,y,m in i[1][['simple','purity','purity']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.15, 0.4)
plt.xlabel(r'$\gamma$')
plt.ylabel('Purity', fontsize=16)
ax3.get_legend().remove()
plt.legend(bbox_to_anchor=(-0.95, 1.2), loc="upper center", ncol=6)

plt.savefig('../result/jideca_real_all.png', format='png', bbox_inches='tight', transparent=True, dpi=300)
plt.savefig('../result/jideca_real_all.eps', format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(10,8))
sns.set_style("ticks", {'axes.grid' : True})
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.35, hspace=0.4)
colors = ['#455E85', '#D68835']

plt.subplot(2, 2, 1)
ax4 = sns.lineplot(x='simple', y='ari', data=df_ari_g, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_ari_g.groupby('types'):
    for x,y,m in i[1][['simple','ari','ari']].values:
        if x == '0.1': i = 0
        elif x == '0.2': i = 1
        elif x == '0.5': i = 2
        elif x == '1.0': i = 3
        else: i = 4
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.22, 0.38)
plt.xlabel(r'$\beta$')
plt.ylabel('ARI', fontsize=16)
ax4.get_legend().remove()

plt.subplot(2, 2, 2)
ax5 = sns.lineplot(x='simple', y='nmi', data=df_nmi_g, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_nmi_g.groupby('types'):
    for x,y,m in i[1][['simple','nmi','nmi']].values:
        if x == '0.1': i = 0
        elif x == '0.2': i = 1
        elif x == '0.5': i = 2
        elif x == '1.0': i = 3
        else: i = 4
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.48, 0.62)
plt.xlabel(r'$\beta$')
plt.ylabel('NMI', fontsize=16)
ax5.get_legend().remove()

plt.legend(bbox_to_anchor=(-0.25, 1.2), loc="upper center", ncol=4)

plt.subplot(2, 2, 3)
ax1 = sns.lineplot(x='simple', y='ari', data=df_ari, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_ari.groupby('types'):
    for x,y,m in i[1][['simple','ari','ari']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0, 0.4)
plt.xlabel(r'$\gamma$')
plt.ylabel('ARI', fontsize=16)
ax1.get_legend().remove()

plt.subplot(2, 2, 4)
ax2 = sns.lineplot(x='simple', y='nmi', data=df_nmi, linewidth=3, palette=colors, hue='types', style='types', markers=True, markersize=14)
for i in df_nmi.groupby('types'):
    for x,y,m in i[1][['simple','nmi','nmi']].values:
        if x == '0.01': i = 0
        elif x == '0.1': i = 1
        elif x == '0.2': i = 2
        elif x == '0.5': i = 3
        elif x == '1.0': i = 4
        else: i = 5
        #plt.text(i-0.2 , y + 0.01, m)
plt.ylim(0.24, 0.65)
plt.xlabel(r'$\gamma$')
plt.ylabel('NMI', fontsize=16)
ax2.get_legend().remove()

plt.legend(bbox_to_anchor=(-0.25, 1.2), loc="upper center", ncol=4)

plt.savefig('../result/jideca_real_all_1.png', format='png', bbox_inches='tight', transparent=True, dpi=300)
plt.savefig('../result/jideca_real_all_1.eps', format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
